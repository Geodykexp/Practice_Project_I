# %%
import pandas as pd

# %%
car_data = pd.read_csv("car_price.csv")

# %%
car_data.head(5)
# Out:
#    Sr_no                                car_name car_prices_in_rupee  \
# 0      0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh
# 1      1            Renault Duster RXZ Turbo CVT          12.83 Lakh
# 2      2                      Toyota Camry 2.5 G          16.40 Lakh
# 3      3                       Honda Jazz VX CVT           7.77 Lakh
# 4      4        Volkswagen Polo 1.2 MPI Highline           5.15 Lakh
#
#    kms_driven fuel_type transmission  ownership   engine    Seats
# 0  86,226 kms    Diesel       Manual  1st Owner  1956 cc  5 Seats
# 1  13,248 kms    Petrol    Automatic  1st Owner  1330 cc  5 Seats
# 2  60,343 kms    Petrol    Automatic  1st Owner  2494 cc  5 Seats
# 3  26,696 kms    Petrol    Automatic  1st Owner  1199 cc  5 Seats
# 4  69,414 kms    Petrol       Manual  1st Owner  1199 cc  5 Seats

# %%
car_data.tail(5)
# Out:
#       Sr_no                    car_name car_prices_in_rupee  kms_driven  \
# 5507   5507     BMW X1 sDrive 20d xLine          28.90 Lakh  45,000 kms
# 5508   5508       BMW M Series M4 Coupe          64.90 Lakh  29,000 kms
# 5509   5509  Jaguar XF 2.2 Litre Luxury          13.75 Lakh  90,000 kms
# 5510   5510          BMW 7 Series 730Ld          29.90 Lakh  79,000 kms
# 5511   5511   BMW 5 Series 520d M Sport          31.90 Lakh  42,000 kms
#
#      fuel_type transmission  ownership   engine    Seats
# 5507    Diesel    Automatic  1st Owner  2995 cc      NaN
# 5508    Petrol    Automatic  2nd Owner  1968 cc  5 Seats
# 5509    Diesel    Automatic  2nd Owner  2755 cc  5 Seats
# 5510    Diesel    Automatic  3rd Owner  2967 cc  6 Seats
# 5511    Diesel    Automatic  2nd Owner  1991 cc  5 Seats

# %%
car_data.iloc[1000:1005]
# Out:
#       Sr_no                                   car_name car_prices_in_rupee  \
# 1000   1000                 Maruti Omni E MPI STD BSIV           1.78 Lakh
# 1001   1001  Mercedes-Benz E-Class E250 CDI Avantgarde          11.21 Lakh
# 1002   1002                     Hyundai i20 Sportz 1.2           3.40 Lakh
# 1003   1003                Hyundai i20 1.4 Asta Option           7.25 Lakh
# 1004   1004       Renault Duster 110PS Diesel RxZ Plus           4.21 Lakh
#
#       kms_driven fuel_type transmission  ownership   engine    Seats
# 1000  11,615 kms    Petrol       Manual  1st Owner  1197 cc  5 Seats
# 1001  85,471 kms    Diesel    Automatic  2nd Owner  1396 cc  5 Seats
# 1002  82,591 kms    Petrol       Manual  1st Owner  1461 cc  5 Seats
# 1003  73,000 kms    Diesel       Manual  1st Owner  1495 cc  5 Seats
# 1004  68,000 kms    Diesel       Manual  1st Owner  1497 cc  5 Seats

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5512 entries, 0 to 5511
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sr_no                5512 non-null   int64
#  1   car_name             5512 non-null   object
#  2   car_prices_in_rupee  5510 non-null   object
#  3   kms_driven           5503 non-null   object
#  4   fuel_type            5506 non-null   object
#  5   transmission         5505 non-null   object
#  6   ownership            5507 non-null   object
#  7   engine               5507 non-null   object
#  8   Seats                5507 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 387.7+ KB

# %%
car_data.describe()
# Out:
#              Sr_no
# count  5512.000000
# mean   2755.500000
# std    1591.321673
# min       0.000000
# 25%    1377.750000
# 50%    2755.500000
# 75%    4133.250000
# max    5511.000000

# %%
import pandas as pd

# %%
car_data = pd.read_csv("car_price.csv", index_col = "Sr_no")

# %%
car_data.head()
# Out:
#                                      car_name car_prices_in_rupee  kms_driven  \
# Sr_no
# 0      Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh  86,226 kms
# 1                Renault Duster RXZ Turbo CVT          12.83 Lakh  13,248 kms
# 2                          Toyota Camry 2.5 G          16.40 Lakh  60,343 kms
# 3                           Honda Jazz VX CVT           7.77 Lakh  26,696 kms
# 4            Volkswagen Polo 1.2 MPI Highline           5.15 Lakh  69,414 kms
#
#       fuel_type transmission  ownership   engine    Seats
# Sr_no
# 0        Diesel       Manual  1st Owner  1956 cc  5 Seats
# 1        Petrol    Automatic  1st Owner  1330 cc  5 Seats
# 2        Petrol    Automatic  1st Owner  2494 cc  5 Seats
# 3        Petrol    Automatic  1st Owner  1199 cc  5 Seats
# 4        Petrol       Manual  1st Owner  1199 cc  5 Seats

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5512 entries, 0 to 5511
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   car_name             5512 non-null   object
#  1   car_prices_in_rupee  5510 non-null   object
#  2   kms_driven           5503 non-null   object
#  3   fuel_type            5506 non-null   object
#  4   transmission         5505 non-null   object
#  5   ownership            5507 non-null   object
#  6   engine               5507 non-null   object
#  7   Seats                5507 non-null   object
# dtypes: object(8)
# memory usage: 387.6+ KB

# %%
car_data.isnull()
# Out:
#        car_name  car_prices_in_rupee  kms_driven  fuel_type  transmission  \
# Sr_no
# 0         False                False       False      False         False
# 1         False                False       False      False         False
# 2         False                False       False      False         False
# 3         False                False       False      False         False
# 4         False                False       False      False         False
# ...         ...                  ...         ...        ...           ...
# 5507      False                False       False      False         False
# 5508      False                False       False      False         False
# 5509      False                False       False      False         False
# 5510      False                False       False      False         False
# 5511      False                False       False      False         False
#
#        ownership  engine  Seats
# Sr_no
# ...

# %%
car_data.isnull().sum()
# Out:
# car_name               0
# car_prices_in_rupee    2
# kms_driven             9
# fuel_type              6
# transmission           7
# ownership              5
# engine                 5
# Seats                  5
# dtype: int64

# %%
car_data.isnull().sum().sum()
# Out:
# np.int64(39)

# %%
car_data.isnull()
# Out:
#        car_name  car_prices_in_rupee  kms_driven  fuel_type  transmission  \
# Sr_no
# 0         False                False       False      False         False
# 1         False                False       False      False         False
# 2         False                False       False      False         False
# 3         False                False       False      False         False
# 4         False                False       False      False         False
# ...         ...                  ...         ...        ...           ...
# 5507      False                False       False      False         False
# 5508      False                False       False      False         False
# 5509      False                False       False      False         False
# 5510      False                False       False      False         False
# 5511      False                False       False      False         False
#
#        ownership  engine  Seats
# Sr_no
# ...

# %%
car_data["kms_driven"] = car_data["kms_driven"].str.replace(",", "")

# %%
car_data.head(5)
# Out:
#                                      car_name car_prices_in_rupee kms_driven  \
# Sr_no
# 0      Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh  86226 kms
# 1                Renault Duster RXZ Turbo CVT          12.83 Lakh  13248 kms
# 2                          Toyota Camry 2.5 G          16.40 Lakh  60343 kms
# 3                           Honda Jazz VX CVT           7.77 Lakh  26696 kms
# 4            Volkswagen Polo 1.2 MPI Highline           5.15 Lakh  69414 kms
#
#       fuel_type transmission  ownership   engine    Seats
# Sr_no
# 0        Diesel       Manual  1st Owner  1956 cc  5 Seats
# 1        Petrol    Automatic  1st Owner  1330 cc  5 Seats
# 2        Petrol    Automatic  1st Owner  2494 cc  5 Seats
# 3        Petrol    Automatic  1st Owner  1199 cc  5 Seats
# 4        Petrol       Manual  1st Owner  1199 cc  5 Seats

# %%
car_data["kms_driven"] = car_data["kms_driven"].str.replace("kms", "")

# %%
car_data.head(5)
# Out:
#                                      car_name car_prices_in_rupee kms_driven  \
# Sr_no
# 0      Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh     86226
# 1                Renault Duster RXZ Turbo CVT          12.83 Lakh     13248
# 2                          Toyota Camry 2.5 G          16.40 Lakh     60343
# 3                           Honda Jazz VX CVT           7.77 Lakh     26696
# 4            Volkswagen Polo 1.2 MPI Highline           5.15 Lakh     69414
#
#       fuel_type transmission  ownership   engine    Seats
# Sr_no
# 0        Diesel       Manual  1st Owner  1956 cc  5 Seats
# 1        Petrol    Automatic  1st Owner  1330 cc  5 Seats
# 2        Petrol    Automatic  1st Owner  2494 cc  5 Seats
# 3        Petrol    Automatic  1st Owner  1199 cc  5 Seats
# 4        Petrol       Manual  1st Owner  1199 cc  5 Seats

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5512 entries, 0 to 5511
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   car_name             5512 non-null   object
#  1   car_prices_in_rupee  5510 non-null   object
#  2   kms_driven           5503 non-null   object
#  3   fuel_type            5506 non-null   object
#  4   transmission         5505 non-null   object
#  5   ownership            5507 non-null   object
#  6   engine               5507 non-null   object
#  7   Seats                5507 non-null   object
# dtypes: object(8)
# memory usage: 387.6+ KB

# %%
car_data["Seats"] = car_data["Seats"].str.replace("Seats", "")

# %%
car_data.head()
# Out:
#                                      car_name car_prices_in_rupee kms_driven  \
# Sr_no
# 0      Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh     86226
# 1                Renault Duster RXZ Turbo CVT          12.83 Lakh     13248
# 2                          Toyota Camry 2.5 G          16.40 Lakh     60343
# 3                           Honda Jazz VX CVT           7.77 Lakh     26696
# 4            Volkswagen Polo 1.2 MPI Highline           5.15 Lakh     69414
#
#       fuel_type transmission  ownership   engine Seats
# Sr_no
# 0        Diesel       Manual  1st Owner  1956 cc    5
# 1        Petrol    Automatic  1st Owner  1330 cc    5
# 2        Petrol    Automatic  1st Owner  2494 cc    5
# 3        Petrol    Automatic  1st Owner  1199 cc    5
# 4        Petrol       Manual  1st Owner  1199 cc    5

# %%
car_data["engine"] = car_data["engine"].str.replace("cc", "")

# %%
car_data.head()
# Out:
#                                      car_name car_prices_in_rupee kms_driven  \
# Sr_no
# 0      Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh     86226
# 1                Renault Duster RXZ Turbo CVT          12.83 Lakh     13248
# 2                          Toyota Camry 2.5 G          16.40 Lakh     60343
# 3                           Honda Jazz VX CVT           7.77 Lakh     26696
# 4            Volkswagen Polo 1.2 MPI Highline           5.15 Lakh     69414
#
#       fuel_type transmission  ownership engine Seats
# Sr_no
# 0        Diesel       Manual  1st Owner  1956     5
# 1        Petrol    Automatic  1st Owner  1330     5
# 2        Petrol    Automatic  1st Owner  2494     5
# 3        Petrol    Automatic  1st Owner  1199     5
# 4        Petrol       Manual  1st Owner  1199     5

# %%
car_data.dropna()
# Out:
#                                      car_name car_prices_in_rupee kms_driven  \
# Sr_no
# 0      Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh     86226
# 1                Renault Duster RXZ Turbo CVT          12.83 Lakh     13248
# 2                          Toyota Camry 2.5 G          16.40 Lakh     60343
# 3                           Honda Jazz VX CVT           7.77 Lakh     26696
# 4            Volkswagen Polo 1.2 MPI Highline           5.15 Lakh     69414
# ...                                       ...                 ...        ...
# 5506                        BMW X5 xDrive 30d          32.90 Lakh     99000
# 5508                    BMW M Series M4 Coupe          64.90 Lakh     29000
# 5509               Jaguar XF 2.2 Litre Luxury          13.75 Lakh     90000
# 5510                       BMW 7 Series 730Ld          29.90 Lakh     79000
# 5511                BMW 5 Series 520d M Sport          31.90 Lakh     42000
#
# ...

# %%
car_data.isnull().sum()
# Out:
# car_name               0
# car_prices_in_rupee    2
# kms_driven             9
# fuel_type              6
# transmission           7
# ownership              5
# engine                 5
# Seats                  5
# dtype: int64

# %%
car_data.dropna(inplace = True)

# %%
car_data.isnull().sum()
# Out:
# car_name               0
# car_prices_in_rupee    0
# kms_driven             0
# fuel_type              0
# transmission           0
# ownership              0
# engine                 0
# Seats                  0
# dtype: int64

# %%
car_data["kms_driven"] = car_data["kms_driven"].astype(int)

# %%
car_data["engine"] = car_data["engine"].astype(int)

# %%
car_data["Seats"] = car_data["Seats"].astype(int)

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5473 entries, 0 to 5511
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   car_name             5473 non-null   object
#  1   car_prices_in_rupee  5473 non-null   object
#  2   kms_driven           5473 non-null   int64
#  3   fuel_type            5473 non-null   object
#  4   transmission         5473 non-null   object
#  5   ownership            5473 non-null   object
#  6   engine               5473 non-null   int64
#  7   Seats                5473 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 384.8+ KB

# %% [markdown]
# # Label Encoding

# %%
import pandas as pd

# %%
import numpy as np

# %%
from sklearn.preprocessing import LabelEncoder
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\ProgramData\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\ProgramData\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
# ...

# %%
car_data = pd.read_csv("car_price.csv")

# %%
car_data.head()
# Out:
#    Sr_no                                car_name car_prices_in_rupee  \
# 0      0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh
# 1      1            Renault Duster RXZ Turbo CVT          12.83 Lakh
# 2      2                      Toyota Camry 2.5 G          16.40 Lakh
# 3      3                       Honda Jazz VX CVT           7.77 Lakh
# 4      4        Volkswagen Polo 1.2 MPI Highline           5.15 Lakh
#
#    kms_driven fuel_type transmission  ownership   engine    Seats
# 0  86,226 kms    Diesel       Manual  1st Owner  1956 cc  5 Seats
# 1  13,248 kms    Petrol    Automatic  1st Owner  1330 cc  5 Seats
# 2  60,343 kms    Petrol    Automatic  1st Owner  2494 cc  5 Seats
# 3  26,696 kms    Petrol    Automatic  1st Owner  1199 cc  5 Seats
# 4  69,414 kms    Petrol       Manual  1st Owner  1199 cc  5 Seats

# %%
encoder = LabelEncoder()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[169], line 1
# ----> 1 encoder = LabelEncoder()
#
# NameError: name 'LabelEncoder' is not defined
