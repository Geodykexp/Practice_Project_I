# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("surat_uncleaned.csv")

# %%
df["BHK"] = df["property_name"].str.extract(r'(\d+)\s*BHK').astype(float)

# %%
df["Location"] = df["property_name"].str.extract(r'in\s+([\w\s]+)$',expand = False).str.strip()

# %%
df["area_type"] = df["areaWithType"].map({
    'Carpet Area' : 1,
    'Super Area' : 2}).fillna(0).astype(int)

# %%
df["area_sqft"] = df["square_feet"].str.extract(r'(\d+)').astype(float)

# %%
df["transaction_type"] = df["transaction"].map({
    'New Property' : 1,
    'Resale' : 2}).fillna(0).astype(int)

# %%
df["ready_to_move"] = df["status"].apply(lambda x: 1 if 'Ready to Move' in str(x) else 0)

# %%
df["furnishing_level"] = df["furnishing"].map({
    'Unfurnished' : 0,
    'Semi-Furnished' : 1,
    'Fully Furnished' : 2}).fillna(0).astype(int)

# %%
df["facing"] = df["facing"].astype('category').cat.codes

# %%
df['price_per_sqft'] = df['price_per_sqft'].str.replace('₹', '', regex=False)\
                                           .str.replace('per sqft', '', regex=False)\
                                           .str.replace(',', '', regex=False)\
                                           .astype(float)

# %%
df.head()
# Out:
#                                        property_name areaWithType square_feet  \
# 0          2 BHK Apartment for Sale in Dindoli Surat  Carpet Area    644 sqft
# 1           2 BHK Apartment for Sale in Althan Surat   Super Area   1278 sqft
# 2          2 BHK Apartment for Sale in Pal Gam Surat   Super Area   1173 sqft
# 3     2 BHK Apartment for Sale in Jahangirabad Surat  Carpet Area    700 sqft
# 4  2 BHK Apartment for Sale in Orchid Fantasia, P...   Super Area   1250 sqft
#
#        transaction            status        floor      furnishing  facing  \
# 0     New Property  Poss. by Oct '24  5 out of 10     Unfurnished     173
# 1     New Property  Poss. by Jan '26  6 out of 14     Unfurnished     156
# 2           Resale     Ready to Move  5 out of 13  Semi-Furnished      54
# 3     New Property     Ready to Move  6 out of 14     Unfurnished      54
# 4  Orchid Fantasia      New Property  Unfurnished               2      12
#
#                                          description  price_per_sqft  \
# 0  Luxury project with basement parking, Solar ro...          2891.0
# 1  2 And 3 BHK Luxurious Flat for Sell In New Alt...          3551.0
# 2  This affordable 2 BHK flat is situated along a...          3800.0
# 3  2 BHK Flat For sell IN Jahangirabad Prime Loca...          3966.0
# 4  Multistorey Apartment for Sale in Palanpur, Su...          3600.0
#
#         price  BHK            Location  area_type  area_sqft  \
# 0  ₹33.8 Lac   2.0       Dindoli Surat          1      644.0
# 1  ₹45.4 Lac   2.0        Althan Surat          2     1278.0
# 2  ₹44.6 Lac   2.0       Pal Gam Surat          2     1173.0
# 3    ₹47 Lac   2.0  Jahangirabad Surat          1      700.0
# 4    ₹45 Lac   2.0                 NaN          2     1250.0
#
#    transaction_type  ready_to_move  furnishing_level
# 0                 1              0                 0
# 1                 1              0                 0
# 2                 2              1                 1
# 3                 1              1                 0
# 4                 0              0                 0

# %%
def convert_price(p):
    if pd.isna(p):
        return np.nan
    p = p.replace('₹', '').replace(',', '').strip()
    if 'Lac' in p:
        return float(p.replace('Lac', '').strip()) * 1e5
    elif 'Cr' in p:
        return float(p.replace('Cr', '').strip()) * 1e7
    else:
        try:
            return float(p)
        except:
            return np.nan

# %%
df['price_rs'] = df['price'].apply(convert_price)

# %%
df =  df.drop(columns=['property_name','areaWithType','square_feet','transaction','status','floor','furnishing','description','price'])

# %%
df = df.dropna()

# %%
df
# Out:
#       facing  price_per_sqft  BHK            Location  area_type  area_sqft  \
# 0        173          2891.0  2.0       Dindoli Surat          1      644.0
# 1        156          3551.0  2.0        Althan Surat          2     1278.0
# 2         54          3800.0  2.0       Pal Gam Surat          2     1173.0
# 3         54          3966.0  2.0  Jahangirabad Surat          1      700.0
# 9         54          3200.0  2.0      Palanpur Surat          1      720.0
# ...      ...             ...  ...                 ...        ...        ...
# 4372      54          6000.0  4.0          Vesu Surat          2     3600.0
# 4379      54          6000.0  4.0          Vesu Surat          2     3700.0
# 4386      54          6000.0  4.0          Vesu Surat          2     4600.0
# 4392      54          6000.0  4.0          Vesu Surat          2     3550.0
# 4398      54          6000.0  4.0          Vesu Surat          2     3650.0
#
#       transaction_type  ready_to_move  furnishing_level    price_rs
# 0                    1              0                 0   3380000.0
# 1                    1              0                 0   4540000.0
# 2                    2              1                 1   4460000.0
# 3                    1              1                 0   4700000.0
# 9                    1              0                 0   4000000.0
# ...                ...            ...               ...         ...
# 4372                 1              0                 0  21600000.0
# 4379                 1              0                 0  22200000.0
# 4386                 1              0                 0  27600000.0
# 4392                 1              0                 0  21300000.0
# 4398                 1              0                 0  21900000.0
#
# [1921 rows x 10 columns]

# %%
df.to_csv("cleaned_data.csv",index = False)
